# %%
import pandas as pd
df=pd.read_csv(r'C:\Users\samir\Desktop\NepSense-main\Profanity and Gender filtered Datas\kantipur-seroiya.csv')

filtered_df = df[df['Profanity'] == 1]
print(filtered_df)
value_counts = df['Profanity'].value_counts()
print(value_counts)
filtered_df.to_csv(r'C:\Users\samir\Desktop\NepSense-main\Profanity and Gender filtered Datas\onlyprofanitylatest.csv',mode='a',header=False,index=False)
# Out:
#       Unnamed: 0 attachments/0/style_list/0 attachments/0/style_list/1  \
# 5              5                        NaN                        NaN
# 10            10                        NaN                        NaN
# 12            12                        NaN                        NaN
# 13            13                        NaN                        NaN
# 17            17                        NaN                        NaN
# ...          ...                        ...                        ...
# 1458        1459                        NaN                        NaN
# 1475        1476                        NaN                        NaN
# 1479        1480                        NaN                        NaN
# 1480        1481                        NaN                        NaN
# 1488        1489                        NaN                        NaN
#
#      attachments/0/style_list/2 attachments/0/style_list/3  \
# ...

# %%
df2=pd.read_csv(r'C:\Users\samir\Desktop\NepSense-main\Profanity and Gender filtered Datas\onlyprofanitylatest.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0.1                376 non-null    int64
#  1   Unnamed: 0                  72 non-null     float64
#  2   attachments/0/style_list/0  0 non-null      float64
#  3   attachments/0/style_list/1  0 non-null      float64
#  4   attachments/0/style_list/2  0 non-null      float64
#  5   attachments/0/style_list/3  0 non-null      float64
#  6   commentUrl                  376 non-null    object
#  7   commentsCount               13 non-null     float64
#  8   date                        376 non-null    object
#  9   facebookId                  376 non-null    int64
#  10  facebookUrl                 376 non-null    object
#  11  feedbackId                  376 non-null    object
#  12  id                          376 non-null    object
# ...
